# %%
import nltk
from datasets import load_dataset

squad = load_dataset('squad_v2')

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# !python -m spacy download en_core_web_sm
# Out:
# Found cached dataset squad_v2 (/Users/v/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)
# 100%|██████████| 2/2 [00:00<00:00, 144.86it/s]
# [nltk_data] Downloading package punkt to /Users/v/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/v/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 8.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: pathy>=0.10.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: setuptools in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (65.6.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.4)
# Requirement already satisfied: jinja2 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/v/miniconda/envs/mthesis/lib/python3.8/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
wikipedia_paragraphs = squad['train']['context']
wikipedia_paragraphs[0]
# Out:
# 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".'

# %%
import spacy
from spacy import displacy

ner = spacy.load('en_core_web_sm')

doc = ner('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'), ('Google', 'ORG'), ('$5.1 billion', 'MONEY'), ('Wednesday', 'DATE')]

# %%
from tqdm import tqdm

def create_NE_collection( paragraphs ):
    output = {}
    for p in tqdm(paragraphs):
        tokens = ner(p)

        for ne in tokens.ents:

            if ne.label_ in output:
                output[ne.label_].append(ne.text)
            else:
                output[ne.label_] = [ne.text]

    for k in output.keys():
        output[k] = list(set(output[k]))
        
    return output

ne_collection = create_NE_collection(wikipedia_paragraphs)
ne_collection
# Out:
# 100%|██████████| 130319/130319 [33:31<00:00, 64.78it/s]
# {'PERSON': ['Mosasaurs',
#   'Yoshimasa',
#   'Louis Aragon',
#   'Bourbon',
#   'Cherry Blossom',
#   'Methodius',
#   'Frederick W. Baldwin',
#   'Dolby Surround',
#   'Hall',
#   'Jan Baudouin de Courtenay',
#   'Kim Kardashian',
#   'Selim the Grim',
#   'Drama',
#   "Arthur] Miller's",
#   'Qīng Cháo',
#   'Skylab',
#   'Dimotiki',
#   'Martin Javeršek',
#   'Francis Collins',
#   'Danté',
#   'Alexander Bard',
#   'Ronald Dworkin',
#   'Ain',
#   'Kota',
#   'Ruili',
#   'Neognathae',
#   'Serapis',
#   'Adolph Zukor',
#   'Mario Palanti',
#   'Hindi',
#   'Hemudu',
#   'West Campus',
#   'John Spilsbury',
#   'George III',
#   'Arne Harris',
#   'Tusculan',
#   'Yucatec Maya',
#   'Ahmose',
#   'Струмички Карневал',
#   'Mel',
#   'Pedro Reinel',
#   'Photius',
#   'Xog Ogaal',
#   'Yasser Arafat',
#   'Monophthalmus',
#   'Stacey Snider',
#   'Robert Stephens',
#   'Johann Wolfgang von Goethe',
#   'Kampuchea',
#   'George Michael',
#   'Utrecht Vaartsche Rijn',
#   'Supercor',
#   'William Fraser',
#   'Juno',
#   'Mehrangarh Fort',
#   'Projet de',
#   'Shitao',
#   'Stelios Kazantzidis',
#   'Karimov',
#   'Lady Chapel',
#   'Jean-François Lyotard',
#   'Agnèz Deréon',
#   'Decca',
#   'Elizabeth Land',
#   'Raul Grijalva',
#   'USS Franklin',
#   'Max von Bahrfeldt',
#   'Cornelius Gallus',
#   'T.E. Lawrence',
#   'Tay Hohoff',
#   'Nat King Cole',
#   'Aztecs',
#   'Nintendo',
#   'William Pitt',
#   'Malintzin',
#   'Benjamin Harrison',
#   'Mies van der Rohe',
#   'Drill',
#   'Chapultepec Zoo',
#   'Saxe-Altenburg',
#   'grey partridge',
#   'West Quay',
#   'Gilbert N. Lewis',
#   'Charles Todd',
#   'John Nash',
#   'Karl Clark',
#   'Porta Nuova',
#   'Gary Langan',
#   'David Brown',
#   'tafseer',
#   'Juan Atkins',
#   'BBC Panorama',
#   'Francis, Duke of Anjou',
#   'Berggarten',
#   'Samuel Dean',
#   'James Bennett Pritchard',
#   'Georgy Beregovoy',
#   'Kenneth Gergen',
#   'Rafe de Crespigny',
#   'Vimara Peres',
#   'C. S. Lewis',
#   'Alfonso XIII',
#   'Cosmos 146',
#   'Woźniak',
#   'Raglan',
#   'Vishishtadvaita',
#   'Klee',
#   'Morris Bates',
#   'Mimi Tachikawa',
#   'Elizabeth Smart-Gilmour',
#   'Yasuzo Takemoto',
#   "John B. Gordon's",
#   'Teruyuki Kato',
#   'Sarbel',
#   'Frostproof',
#   'Robert Wagner',
#   'Herb Quinn',
#   'Avalokiteśvara',
#   'an "Ann Arborite',
#   'Tepehuan',
#   'Coustou',
#   'Hasan Mellâh',
#   'Lorde',
#   'Eric F. Wieschaus',
#   'Honorary Membership',
#   'Beatrice',
#   'Chandragupta II - brought',
#   'Aolepān Aorōkin',
#   'Digimon Savers',
#   'Immanuel Velikovsky',
#   'Volksrechte',
#   'Norman Hartnell',
#   'Andrei Bogolyubsky',
#   'menarche',
#   'Visible Speech',
#   'Mudaito',
#   'the Belgian Interbrew',
#   'Volga Rivers',
#   'A-4',
#   'McDonough',
#   'Bonny',
#   "Franklin D. Roosevelt's",
#   'André Dunoyer de Segonzac',
#   "Xiang Yu's",
#   'Dusty Baker',
#   'Kerala Nadvathul Mujahideen',
#   'Favre',
#   'Berchtold V',
#   'Coop Himmelbau',
#   "Don Zimmer's",
#   'Charles Sheffield',
#   'Wolff et al.',
#   'Utrecht Overvecht',
#   'Park Place',
#   'Nathaniel Mayer',
#   'J.G. Ballard',
#   'Alan Grant',
#   'Apella',
#   'Frank Welker',
#   'Samuel Adelstein',
#   'Chains',
#   'Wolfe',
#   'Friedrich Nietzsche',
#   'Randall Ripley',
#   '.8473',
#   'George Grey Wornum',
#   'the Collins Bartholomew',
#   'Donda West',
#   "Medieval Europe's",
#   'Agnes Shea',
#   'Peter',
#   'Qiu',
#   'Martin V',
#   'Hasayn Abu Zubaydah',
#   'Hun',
#   'Valencia Airport',
#   'Ernest Renan',
#   'Arne Frager',
#   'John Soane',
#   'Σθλαβηνοί Sthlabenoi',
#   'Josip "Joška" Broz',
#   'Conrad von Gesner',
#   'Xenophon',
#   'Bernard Montgomery',
#   'Carlo Maratta',
#   'Bob Filner',
#   'Angela Mace,1986',
#   'The Generalitat of Catalunya',
#   'Gabriel Nicolas de la Reynie',
#   'Barber',
#   'Vírgen de Socavon',
#   'Josiah Nott',
#   'Ken Livingstone',
#   'Offstage Beyoncé',
#   'Caroline Rose',
#   'Hafiz',
#   'Raghuram Rajan',
#   'Nikayas',
#   'Peter J. Wallison',
#   'Jim Meyer',
#   'Mir Osman',
#   'Michael Kahn',
#   'Max Planck',
#   'Jacob',
#   'Lamido Sanusi',
#   "Walter Bagehot's",
#   'Herbert',
#   'Jean-Claude Trichet',
#   'Antonino Sancho',
#   'Brian Deane',
#   'Batavia Joosten',
#   'Sakya Pandita',
#   'Bhāskara',
#   'Jama Masjid',
#   'Rod Beck',
#   'Valouro',
#   'Mesoamerica',
#   'Code Talkers',
#   'Philip Jackson',
#   'Evans Head',
#   'Patrick Runyon',
#   'Ballon',
#   "Jason Castro's",
#   'Pedro II',
#   'M. Hassan Kakar',
#   "Marie d'Agoult's",
#   "Hermann von Helmholtz's",
#   'Saturn',
#   'Gwenllian Evans',
#   'Dennis Weaver',
#   'Karin Björnson',
#   'Viscount Bearsted',
#   'Prince Gui',
#   'Richard M. Daley',
#   'Mintz',
#   'Hyper Fighting',
#   'Luke',
#   'Nat Turner',
#   'Pixel Pancho',
#   'Luc Sante',
#   'Lachenmann',
#   'Milton Rackmil',
#   'Terry Venables',
#   "Sergei Prokofiev's",
#   'cyclodiene compounds',
#   'Canzoniere',
#   'London Scottish',
#   'John Summerson',
#   'David Banda',
#   'Mentha ×',
#   'Tarsus of Cilicia',
#   'Aqa Mohammad Khan',
#   'Ben van Beurden',
#   'Thaddeus Kosciuszko',
#   'Theatre Tulsa',
#   'Hussein Ahmed Salah',
#   'Kallaikói',
#   'Sikander Lodi',
#   'Aaron',
#   'Madonna-Eva',
#   'Tito Vilanova',
#   'Seleucia',
#   'Stella',
#   'Ranulph Glanville',
#   'İbn Sina',
#   'Lent',
#   'SNF8',
#   'Spielberg',
#   'Joe Jamail Skatepark',
#   'Baena',
#   'Abi Jahl',
#   'Apps',
#   'Apollodotus',
#   "Zeid Ra'ad",
#   'Nefertiti',
#   'Joseph N. Grasso',
#   'Gaspar Castaño',
#   'Superstar Billy Graham',
#   'Murex',
#   'Laurisilva',
#   "Bill O'Neill",
#   'Herbert Morrison',
#   'Ouachita Mountains',
#   'Christopher M. Tuckett',
#   'apps run',
#   'Statute §',
#   'Brenodor',
#   'Walt Disney-produced',
#   'Victor',
#   'Assa Abloy',
#   'Pitt',
#   'Ortiz Taranco',
#   'Janapada',
#   "Sigmund Freud's",
#   'Technikons',
#   'M17',
#   'Ishida',
#   'Jabr',
#   'Alexander Ellis',
#   'Larry Bowa',
#   'Wang Fu',
#   'Henri Guisan',
#   'lashun ki chutney',
#   'Zhu Shaowei',
#   'Charles Sumner Tainter',
#   'Nicholas Lezard',
#   'Arthur Collier',
#   'Bloomberg Online',
#   'L. Schwabe',
#   'Deval Patrick',
#   'Terrazas',
#   'Abigail Breslin',
#   'Jean Chretien',
#   'Mainz',
#   'John Davenport',
#   'European Footballer',
#   'Konbaung Dynasty',
#   'Tionól Pharlaiminteach',
#   'Labour',
#   'Heather Fong',
#   'Manolis Andronikos',
#   'Hal B. Wallis',
#   'Hailsham',
#   'Acraephius',
#   'Haredi Judaism',
#   'Earl de Grey',
#   'C. Robert Mesle',
#   'Newgate Prison',
#   'Hiram S. Maxim',
#   'Kara',
#   'Sarah Fuller',
#   'Pamiris',
#   'Mohammed Magariaf',
#   'Andrés Manuel López Obrador',
#   'Carl Rowan',
#   'Coen',
#   'anno salutis MDCCCXXXIV',
#   'Holocene Epipaleolithic',
#   'Newell',
#   'Tacita',
#   'John McArthur',
#   'Abulcasis',
#   'Sefton',
#   'Alcoy',
#   'C. R. Dodwell',
#   'Perry Como',
#   'Erich Honecker',
#   'Diplom Uni',
#   'Qin Empire',
#   'Latimer',
#   'Tom Playford',
#   'Mikhail Lomonosov',
#   'Royle',
#   'Cuttack',
#   'Robert H. Cochrane',
#   'Café de la Rotonde',
#   'Great Highland',
#   'Louis Kahn',
#   'André de Lorde',
#   'Norman North',
#   'Geoffrey Maruyama',
#   'da',
#   'Green Beret',
#   'Madhav Deshpande',
#   'Sughd',
#   'groups Zp',
#   'Alexandra Dock',
#   'James McBride',
#   'Taylor Swift',
#   'Denis Diderot',
#   'Rocks',
#   'Lennon',
#   'Zwingli',
#   'Wojciech Żywny',
#   'Tucson Lifestyle Magazine',
#   'Krueger',
#   "Karl Marx's",
#   'Gopala',
#   'Norman Holmes Pearson',
#   'Porfiriato',
#   'John Milius',
#   'Bleiburg',
#   'Lambeth Bridges',
#   'Alberti',
#   "Don Bosco's",
#   'Dwayne Johnson',
#   'Miocene',
#   'Joan Laporta',
#   'Taylor Report',
#   'Card Slash',
#   'Billy Graham',
#   'Raxaul',
#   'Rooster Cogburn',
#   'the Cadet Wing',
#   'Sandringham',
#   "Flannery O'Connor",
#   'Chief Priest',
#   'botanē',
#   'Superstores',
#   'Walid ibn Uqba',
#   'Eric Ericson',
#   'Barak',
#   'Dan Gilroy',
#   'USS Farragut',
#   'Lo Rat Penat',
#   'Harihara',
#   'Bass House',
#   'Basso Continuo',
#   'Scarlett',
#   'Seneca',
#   'John Still',
#   'Afrotheria',
#   'Pasofami',
#   'Chuck Aaron',
#   'Cleopatra',
#   'Sam Nujoma',
#   'Duo',
#   "Michael Jackson's",
#   'William Adams',
#   "Harvey saw McCloud's",
#   'Bluegrass',
#   'Franklin I. Gamwell',
#   'Elizabeth Loftus',
#   'lighter fluid',
#   'Charles Johnson',
#   'Arlington Hall',
#   'Fourier',
#   'Saint Justinian',
#   'Christopher Orr',
#   'Thomas Jefferson',
#   "de l'Université de Strasbourg",
#   'Organ Sharing',
#   'Vlastislav Hofman',
#   'USS Yorktown',
#   'M.Sc.',
#   'Kitt',
#   'Nursultan Nazarbayev',
#   'Erythra Thalassa',
#   'Hiryū',
#   'Chic-Chocs',
#   'Castleshaw',
#   'Joshua Reynolds',
#   'América',
#   'Ramzi bin al-Shibh',
#   'Christensen',
#   'George Westinghouse',
#   'Helen Meles',
#   'Casimir II',
#   'Latino American',
#   'Finne',
#   'Oberhauser',
#   'Ben Ali',
#   'Hempel',
#   'dolmas',
#   'Filner',
#   'C3',
#   'Marcus Tullius Cicero',
#   'Myra',
#   'Chmielnicki Cossack',
#   'Chonan',
#   'Henry de Costa',
#   'Train',
#   'Chumash',
#   'Sardica',
#   'Paul Ekman',
#   'Albert L. Weeks.[page',
#   "Sun Yat-sen's",
#   'Fernand Bonnier de La Chapelle',
#   'Itinerant Commandery',
#   'Phil Stacey',
#   'Alfredo Ottaviani',
#   "al-'aql al-fa'il",
#   'scholae monasticae',
#   'Jesus',
#   'Gerald R. Ford',
#   'L.A. Reid',
#   'Joseph the Betrothed',
#   'Outer London',
#   'Vitamins',
#   'Appalaches',
#   'Mythologies',
#   'Rowan Williams',
#   'Julian Huxley',
#   'Seth Meyers',
#   'Alain Rey',
#   'Soyots',
#   'George Harrison',
#   'Charles "Wag" Bennett',
#   'Gudmundur Alfredsson',
#   'Jingle',
#   'Robert Jones',
#   'Donald Byrd',
#   'Lauryn Hill',
#   'Regicides Trail',
#   'Neo-Egyptian',
#   'Gorbachev',
#   'Place Gutenberg',
#   'Chris Benoit',
#   "Marshal Bazaine's",
#   'Ranger',
#   'Homo',
#   'Ruben Studdard',
#   'Eretz Yisrael',
#   'Krajišnici',
#   'Lighter Rock',
#   'al-Sakhawi',
#   'Robert Lopez',
#   'Zhu Yihai',
#   'George',
#   'King Mithridates',
#   'Fianna Fáil',
#   'Doom',
#   'Santiago Baca Ortiz',
#   'Sekigahara',
#   'Smintheus',
#   'Sondershausen',
#   'Santa Maria Maggiore',
#   'grondwet',
#   'Viśiṣṭādvaita',
#   'Bob Bemer',
#   'Edward Itta',
#   'Satoru Iwata',
#   'Gordon Laing',
#   'Mortu Nega',
#   'Jamahiriyah',
#   'Kong Youde',
#   'Prince Antoni Radziwiłł',
#   'Vanu Bhuta',
#   'Alexander III',
#   'Desert',
#   'Gaddafi',
#   'Bashar al-Assad',
#   'Antiochus III',
#   'Latin Graeci',
#   'Radoje Ljutovac',
#   'Tina Turner',
#   "Casimir Pulaski's",
#   'Albert Grey',
#   'Fastelavn',
#   'Hekaergos',
#   'George Keith',
#   'Flash',
#   "Anton Hansen Tammsaare's",
#   'Sebastián Vizcaíno',
#   'Mangriha',
#   'Edward Abraham',
#   'Hank Brown',
#   'Kevyn Orr',
#   'Philip Graves',
#   'Dhami',
#   'London Zoo',
#   'Cubbie',
#   'Kuaiji Commandery',
#   'Chip Caray',
#   'Saint Denis Basilica',
#   "Robert De Niro's",
#   'Tom Brokaw',
#   'Resident',
#   'Guano',
#   "Henry Jaglom's",
#   'Diana',
#   'Matthew Trammell',
#   'Robert Doisneau',
#   'Rillito Downs',
#   'Spoken',
#   'Brian May',
#   'Saboteur',
#   'Ray West',
#   'John Thadeus Delane',
#   'David Horsley',
#   'South Campus',
#   'Marcus Furius Camillus',
#   'Josh Homme',
#   'Jordan of Saxony',
#   'David Whitney Building',
#   'Patrick McHenry',
#   'Plymouth Brethren',
#   'Queen II',
#   'de Lisboa',
#   'Emily Brontë',
#   'Ron Castille',
#   'Itzhak Perlman',
#   'Schweizer',
#   'Romance',
#   'Marie Laurencin',
#   'Adam Fogelson',
#   'Mick Foley',
#   'Roger II',
#   'Gordon Lang',
#   "Jacob M. Appel's",
#   'John Loughborough Pearson',
#   'Luddi',
#   'Partenkirchen',
#   'Duke Constantine',
#   'Palamas',
#   'Melvin',
#   'Robert De Niro',
#   'Roger Sherman',
#   'Oskar Wahl',
#   'Jules Chéret',
#   'Peel',
#   'Paideia',
#   'Rabbi Shammai Engelmayer',
#   'Bohdan Khmelnytsky',
#   'Carlos Leon',
#   'Donnie Brasco',
#   'Duccio',
#   'Alfonso VI of León',
#   'Jawahar Sagar',
#   'Al Jamiatul Ashrafia',
#   'BSkyB',
#   'Archie Bunker',
#   'Luis Crespi',
#   'Dave Finlay',
#   'Harry Gordon Selfridge',
#   'Levellers',
#   'Avenue C. West',
#   'Dahlgren',
#   'F. G. Keller',
#   'Marija',
#   'King Hussein',
#   'Mark 14',
#   'A. P. de Candolle',
#   'Sahitya Akademi',
#   'Yellow Tiger',
#   "Semyon Dezhnyov's",
#   'John Galsworthy',
#   'Michael Stonebraker',
#   'Stephan Kinsella',
#   'Theodor Schwann',
#   'Giuseppe Zanotti',
#   'Nehru',
#   'Bouvet',
#   'Felix Adler',
#   'Vaud',
#   'Yongying',
#   'Jodhpur Marwar',
#   'Graeco-Roman',
#   'Gesta Friderici Imperatoris',
#   'Johann Friedrich Naumann',
#   'Hobart Taylor Jr.',
#   'Rattlers',
#   'Renton',
#   'François Joseph Lefebvre',
#   'Marsha Weidner',
#   'Cerberus',
#   'Philip Hamburger',
#   'Jodie Markell',
#   'Vaqueros',
#   'Robert Sommers',
#   "Galerías Preciados'",
#   'William Bateson',
#   'Voodoo',
#   'Copra',
#   'Sol Invictus',
#   'Level 9',
#   'Nwafor Orizu',
#   'Abd al-Rahman',
#   'Daxia',
#   'Elaine Goodale',
#   'Plymouth Hoe',
#   'Dick Dale',
#   'Joe Simon',
#   'James Dewar',
#   'Ron Greenwood',
#   'Semi-Arid Plain',
#   'Juan Aldama',
#   'Jaume Picas',
#   'Chitralada Palace',
#   'Manuel Vázquez Montalbán',
#   'Wilhelm von Hofmann',
#   'Cavaco Silva',
#   'David Kipen',
#   'The Bee Gees',
#   'Alfonso O Sabio',
#   'Once John',
#   'Miklós Rédei',
#   'Eddie',
#   'Danny Sherrard',
#   'José Enrique Serrano',
#   "St Nicholas's",
#   'Amor Flores',
#   'Austin',
#   'Bowersox',
#   'Otto II',
#   'Paul VI',
#   'Maria Letizia Ramolino',
#   'XON',
#   'Alushe',
#   'Wang Fuchen',
#   'Chapultepec',
#   'MANPADs',
#   'Scotty McCreery',
#   'Catherine Howard',
#   'Colton Dixon',
#   'Lyndon Johnson',
#   'Mill',
#   'Doud Dwight "',
#   "The Barrière de l'Esseillon",
#   'Nikolai Yudenich',
#   'Darwin',
#   'Herbert Mataré',
#   'Perfect Harmony',
#   'Anglesey',
#   'Loch Lomond',
#   'Hugh McGregor Ross',
#   'Xunta',
#   'Germanizing',
#   'François Achille Bazaine',
#   'Friar Antonio de la',
#   'William Allen White',
#   'Tarahumara',
#   'Jew',
#   'Ďáblice Cemetery',
#   'Ange-Jacques Gabriel',
#   'Cap Anson',
#   'Peithon',
#   'Edward Burne-Jones',
#   'Dean Amadon',
#   'Albemarle Point',
#   'Greater Boston',
#   'Corso Tukory',
#   'Gloucester Cathedral',
#   'Antonio Inoki',
#   'Derrick May',
#   'Nicholas I',
#   'Kate Norgate',
#   'Gan Ying',
#   'Partner Wormmon',
#   'Joe Weider',
#   'Archduke Charles',
#   'Bouaké',
#   'William Goetz',
#   "the Kievan Rus'",
#   'Ranulph Fiennes',
#   'Leonardo da Vinci',
#   'Melbourne Storm',
#   'William Huse',
#   'Deux Femme',
#   'Ian Jeffries',
#   'Pretty Tony',
#   'Cervantes',
#   'Lewis Latimer',
#   'Maurizio Pollini',
#   'das Hohe Ufer',
#   'Triumvir',
#   'Serif',
#   'Khoshut',
#   'Light Asylum',
#   'Kahal Kadosh Beth Shalom',
#   'Chicxulub Crater',
#   'Ernst Cassirer',
#   'Guianas',
#   'Eric Bana',
#   'Arthur Golden',
#   'Moore',
#   'Mecklenburg-Strelitz',
#   'John Punch',
#   'Huckleberry Finn',
#   'al-Borkan',
#   'Pierre Macquer',
#   'Avon Canal',
#   'Salam',
#   'Lonnie Donegan Showcase',
#   'Henri Laurens',
#   'Edward Grant',
#   'Sviatoslav',
#   'Policy',
#   'Disco Beat',
#   'the Adidas Yeezy Boosts',
#   'Gnaeus Manlius Vulso',
#   'al-Waqidi',
#   'Luckett',
#   'Coyoacán',
#   'William Wilberforce',
#   'Tokuko',
#   'description de tous',
#   'Hale Boggs',
#   'Geoffrey Roberts',
#   'kuul',
#   'Ptolemy Dean',
#   'Yannis Tsarouchis',
#   'Angers.[nb',
#   'Standard Arabic',
#   'Zhang Dejiang',
#   "Orson Welles's",
#   'Zebulon Baird Vance',
#   'Du Yuesheng',
#   'Ronald Fisher',
#   'Dutch Lonborg',
#   'Bojangles',
#   'Jared Diamond',
#   'Kagerō Nikki',
#   'Lucani',
#   'The Nivaga III',
#   'Begin',
#   'Jane Frazee',
#   'Herbert Grönemeyer',
#   'Sixaxis',
#   'Foguer',
#   'Tsuga',
#   'Edward Whymper',
#   'Mark C. Taylor',
#   'Budhanilkantha',
#   'Mecca Masjid',
#   'Haq',
#   'Ted Stevens Anchorage International Airport',
#   'Yoma',
#   'David Steel',
#   'Khosrow Sinai',
#   'Local',
#   'Jonathan Sallet',
#   'Kerim Kerimov',
#   'Julian Haviland',
#   'Samskrita Bharati',
#   'Pierre Mignard',
#   'Abd Allah al-Sulami',
#   'Tottenham Hotspur',
#   'Cologne Carnival',
#   'Brandenburg',
#   'Olsen',
#   'Arthur',
#   'Alys',
#   'Michael Collins',
#   'Randall Wallace',
#   'Philip Green',
#   'Walter Hecht',
#   'Cinco Chagas',
#   "George Onslow's",
#   'Frank Lambert',
#   'Pedro Nunes',
#   'Hamid Ali Bela',
#   'Windows Store',
#   'Tsang',
#   "Salman Khan's",
#   'Muhammad al-Nasir',
#   'Zamoyski',
#   'Sentinel Peak',
#   'Frank J. Sprague',
#   'Verité',
#   'Sremci',
#   'Jefferson Davis Highway',
#   'Sammitya',
#   'Boyer',
#   'Jean Pierre Philippe Lampué',
#   'Herod Agrippa II',
#   'Baltica',
#   'Assam',
#   'Mohamed Deq Abdulle',
#   'Robert Schumann',
#   'Olivier Theyskens',
#   'Henri Poincaré',
#   'Luo Xuejuan',
#   'Visc',
#   'Jasmine Trias',
#   'Danny Tenaglia',
#   'Regis McKenna',
#   'Hollande',
#   "Wilhelm Erb's",
#   'John Rut',
#   'Nea Moni',
#   'Acheson',
#   'Viollet',
#   'Mark Cooper',
#   'André le Nôtre',
#   'Steppe',
#   'Bray',
#   'John C. Bowen',
#   'Moltacqua',
#   'Mirpur Jain Temple',
#   'A. L. Arefyev',
#   "Carl, Jr.'s",
#   'Bobby McFerrin',
#   'Edward Heath',
#   'Alfonso III',
#   'Anjiro',
#   'Treasurer John Howard',
#   'Playground',
#   'Mel Lewinter',
#   'Roger Peyrefitte',
#   'H. Becker',
#   'David McKee',
#   'University Jaipur',
#   'Attica',
#   'Gregory',
#   'Friedrich Wilhelm Murnau',
#   'Jubilee',
#   'Carlos Vaz Ferreira',
#   'Edward',
#   'Llywelyn',
#   'Lotfi Zadeh',
#   'bin Laden',
#   'Consort Liang',
#   'Prince Andrey Bogolyubskiy',
#   'Araniko',
#   'Hangul',
#   'Emanuel Goldberg',
#   'Johnny Todd"',
#   'Croatia',
#   'Charles White',
#   'Rama',
#   'Lisle',
#   'Carles Comamala',
#   "Musée d'art",
#   'Jeh Johnson',
#   'George Earle Buckle',
#   'John Burgoyne',
#   'Art Car Parade',
#   'Shubra Khit',
#   'J.C.D.',
#   'Adolphe Gutmann',
#   'Patrick Hillery',
#   'Bobangi',
#   'Aguilera',
#   'Emmanuel Nunes',
#   'Robert D. Richtmyer',
#   'Mārtiņš Bariss',
#   'Lucius Sergius Catilina',
#   'Guillaume de Machaut',
#   'Karachays',
#   'Peter Salovey',
#   'Sell',
#   'Hunt',
#   'Soha Ali Khan',
#   'Griselda',
#   'the George Medal',
#   'Howard Armstrong',
#   'António Costa',
#   'Tornado Alley',
#   'Burkina Faso',
#   'Roger Bucknall',
#   'Joe Smooth',
#   'Hexi Corridor',
#   'John Briggs',
#   'Mühlhausen',
#   'David Bohm',
#   'Amorpha',
#   'Jack Whittingham',
#   'Bob Mackie',
#   'Tom Hardy',
#   'Antonio Azarola',
#   'Von Juraschek',
#   'Graham',
#   'Jeanneret',
#   'Danny Brown',
#   'Ganzi',
#   'Monica Pier',
#   'Breakthrough',
#   'Walter Baily',
#   'Islam Shah Suri',
#   'St John Ambulance',
#   'Nicholas Rescher',
#   'Bakken Formation',
#   'Holiness Syedna Mufaddal Saifuddin',
#   'Prakrit',
#   'Daphnis',
#   'Cyndi Lauper',
#   "Modest Mussorgsky's",
#   'Trochu',
#   'Ben Kingsley',
#   'Halmos',
#   'Daniel Finkelstein',
#   'dharma',
#   "Once Mutaguchi's",
#   'Haber',
#   'Justin Vernon',
#   'Lady Diana Spencer',
#   'Fridericus Franciscus',
#   'Wendell B. Blancke',
#   'Jeff Shell',
#   'Kaṇāda Kaśyapa',
#   'Edward S. Harkness Stone',
#   'Hijaz',
#   'Médica Sur',
#   'Matthew Fitzsimons',
#   "Louis Malle's",
#   'Zeven Verenigde Provinciën',
#   'Jhamel',
#   'Gloria Estefan',
#   'Donn Barber',
#   'John Freeman',
#   "Bazar de l'Hotel de Ville",
#   'Emilio Martínez Garrido',
#   'Order 9808',
#   'Maverick',
#   'Yusuf bin Umar',
#   'Charlie Hebdo',
#   'Peter III',
#   "Shoji Nishimura's",
#   'Aleksandar Matunović',
#   'Vsevolod',
#   'Tate Modern',
#   'Wang Mang',
#   'Lokāyata',
#   'Polly Ha',
#   'Anastasio Bustamante',
#   'Nicholas Kaldor',
#   'Arthur B. Gunlicks',
#   'Seibu',
#   'Monte Rosa',
#   ...],
#  'ORG': ['U.S. Army',
#   'Iowa Barnstormers,',
#   'the National Survival',
#   'the American Standards Association',
#   'DOE',
#   'The Human Development Report',
#   'the Marine Institute',
#   "the New England Conservatory's",
#   'Innoson Motors',
#   'Sorbs',
#   'Ekman',
#   'Wertheim Performing Arts Center',
#   'Mariology',
#   'Marvel Entertainment',
#   'Methodius',
#   'Brig-Visp-Zermatt Bahn (BVZ',
#   'UO',
#   'Blue Cross Blue Shield',
#   'Derby reprimanding him',
#   'Motulsky',
#   'Pyrénées-Orientales',
#   'Grzymała',
#   'Nanjing City Wall Cultural Museum',
#   'Harjavalta',
#   'the E. W. Scripps Company',
#   'Imperial Preceptor',
#   'the Institute for the Postmodern Development of China',
#   'Dimotiki',
#   'Officer Reserve Corps',
#   'Universal Primary Education',
#   'DNA/RNA',
#   'MasterChef',
#   'Canadian Forces',
#   'Baie de Grand Cul de Sac',
#   'the Sheffield Scientific School',
#   'SERI',
#   'Adventure',
#   'Registrar',
#   'Clopidogrel',
#   'Maple Leaf',
#   'Buniv, Kalush, Hoshiv',
#   'The Sainte-Geneviève Library',
#   'the Alemannic Swiss German',
#   'Hindi',
#   'Devonport High School for Girls, Devonport High School for Boys and',
#   'the District Courts',
#   'Maghreb',
#   'the Himachal Pradesh (Administration',
#   'non-Mahayana Buddhism',
#   "Entertainment Weekly's",
#   'the Regional Exhibition',
#   'AES',
#   'The Lowcountry Oyster Festival',
#   'the Honors Program',
#   'P&O',
#   'the Spanish Civil War',
#   'Devimon, Etemon',
#   'Cross-Niger',
#   'Ἰατρομάντις',
#   'the Suez Canal Company',
#   'Girl',
#   'Budapest-Nyugati',
#   'Meredith College',
#   'the University of Bologne',
#   'house',
#   'SMS Arminius',
#   'Fall Semester 1965',
#   'Families',
#   'Juno',
#   "BBC One's",
#   'The Japanese Army',
#   'the Charing Cross',
#   'the US Copyright Office',
#   'GPC',
#   'AKA',
#   'Searching for Consensus',
#   "Ephraim Chambers'",
#   'LSU',
#   'Old Guard',
#   'the Delhi Metro Rail Corporation Limited',
#   'Jean-François Lyotard',
#   'Western Yiddish',
#   'Rubens',
#   'Treasury Services',
#   'Aspern and Essling',
#   'AIFF',
#   'Camels',
#   'L.A. Rush',
#   'the Australian Technology Network',
#   'Les Sylphides',
#   'the Chicago Reader',
#   'the Mornington Peninsula National Park, Port Phillip Heads Marine National Park',
#   'ITT Corporation',
#   'TYS',
#   'the U.S. Central Intelligence Agency',
#   'the Virginia Center for Architecture',
#   'MGM/UA',
#   'the Football Championship Subdivision',
#   'Aztecs',
#   'Nintendo',
#   'OPC',
#   'Miami Sun Post',
#   'the Pioneer Corps',
#   'Robbins invited Hayek',
#   'Rolling Stones',
#   'Ourense and Lugo',
#   'the Samoa Rugby Football Union',
#   'the Myanmar Tourism Promotion Board',
#   'Fannie Mae',
#   'Military Intelligence Service',
#   'The Telemundo Television Studios',
#   'Ultimate Power',
#   'the National Security Council',
#   'YYT',
#   'the United Kingdom Hydrographic Office',
#   'Pew Research Center',
#   'Haddon House',
#   'Avicenna Medical College',
#   'Carpet',
#   'New Haven Register',
#   'Mass Action',
#   'the Forest of Bowland',
#   'Eigentums',
#   'LSWR',
#   'the Richmond School Board',
#   "Social Darwinism and Lewis Henry Morgan's",
#   'the Royal College of Art',
#   'the State Senate',
#   'Stratus',
#   'CWA',
#   'Mourelle',
#   'Unspunnenstein',
#   'Samsung Electronics',
#   'the Oklahoma City Skate Park',
#   'Stryker',
#   'the World Council of Churches Fredrik A. Schiotz',
#   'Staats-Limburg',
#   'Biltmore Estate',
#   'Campbell University',
#   'Houck',
#   'the Moti Azima Gallery',
#   "Universal-International's",
#   'DuPont',
#   'the Consentimiento Real (Royal Assent',
#   'the Canadian Forces Information Operations Group',
#   'the Warsaw Pact',
#   'the Best Supporting Actress Academy Award',
#   'the King and Queen',
#   'wolna',
#   'Komnenos',
#   'Native American',
#   'McPhee',
#   'the Pacific Ring of Fire',
#   'Non-Hispanic Whites',
#   "the King's Works",
#   'Coptic Orthodox Church',
#   'the Yale School of Nursing',
#   'Comcast SportsNet',
#   'the Rhaetian Railways',
#   'Salafis',
#   'Moores Creek National Battlefield',
#   'Parque Natural',
#   'The Eddy Street Commons',
#   'Weston Mill',
#   'Lynda',
#   'Rr / (Rr + Rloss',
#   'Upper School',
#   'The Nuclear Science Department',
#   'Andhra State',
#   'Garrett-Evangelical Theological Seminary',
#   'CNO',
#   'Digital 3D',
#   'the Guanxian–Anxian Fault',
#   'the Potsdam Conference',
#   'Orioles',
#   'Clingmans Dome',
#   'the Thomson Reuters Corporation',
#   'the Great School',
#   'The Executive Board',
#   'the New Haven Green',
#   'Public Broadcasting Service',
#   'Kęsgailos',
#   'SanDisk',
#   'the Dutch Revolt',
#   'Taíno Cacique',
#   'Morley-Minto',
#   'Digital-VHS',
#   'the Interactive Digital Software Association',
#   'Barthes',
#   'the Order of Labor red Banner',
#   'the Theatre Royal',
#   'Tarragona',
#   'Beatrice',
#   'the Alma Mater',
#   'Pahlavi',
#   'Royal Dutch',
#   'a Democracy Score of 5.21',
#   'the International Song Project',
#   'Rawlinson, Layard',
#   'Wordsworth',
#   'menarche',
#   'Office of Sustainability',
#   'Southampton Hockey Club',
#   'the Descent of Man',
#   'World Heritage Sites',
#   'the Lanarkshire Guitar and Mandolin Association',
#   'Nama, Orlams',
#   'AAT',
#   'Muslim Student Association',
#   'The Avicenna Directories',
#   'the Baltimore Orioles',
#   'Organization for Security',
#   'Yankees',
#   'Interior',
#   "Women's University",
#   'Clausius',
#   'Ariana Grande',
#   'Magistrate',
#   'Crown Hill',
#   'Proto-Czech',
#   'Non-Conformity',
#   'DALYs',
#   'The Blind Man Museum',
#   'the Xbox Live Vision',
#   'the Apple Industrial Design Group',
#   'UPRR',
#   'German Baumwolle',
#   'Southern Cross Station',
#   'The University of Kansas School of Business',
#   'Afro-Spaniards',
#   'the Democratic Caucus',
#   'the Ethnologue of Languages',
#   'Journal of the Plague Year',
#   'Recruit School',
#   'University of al-Qarawiyyin',
#   'the British India Command',
#   'the Great American Novel',
#   'Canterbury Cathedral',
#   'General Services Administration',
#   'Dominions',
#   'The Armenian Army',
#   'the Prussian 40th Regiment',
#   'the Institute of Electrical and Electronics Engineers',
#   'ZIF',
#   'Ronaldinho',
#   'Skepi',
#   'the Cooper River Bridge Run',
#   'the Joan B. Kroc Institute for International Peace Studies',
#   'sham',
#   'Mantons de Manila',
#   'Inzunza',
#   'Hafiz',
#   '35th Ave SW',
#   'pre-Constitutional United States Federal',
#   'Home Rule for Ireland',
#   "Burke's Thoughts and Details on Scarcity",
#   'Maharaja Ranjeet Singh',
#   'Walter of Coutances',
#   'Anheuser-Busch',
#   'the Bernese Oberland',
#   'the North African Theater of Operations',
#   'the British Crown',
#   'the Detroit Public Library',
#   'Astronomy, Banks (conservation)',
#   'SA',
#   'KBYU-FM Classical 89',
#   'East Resources',
#   'the SNES Mouse',
#   'the Corpus Juris Civilis',
#   'CareJet',
#   'recently[when',
#   'the United States Department of Transportation',
#   'the Old Summer Palace',
#   'GIOVE',
#   'Patience Latting',
#   'El Bracito',
#   'the Origin of Species',
#   'al-Qarawīyīn',
#   'the NES/Famicom',
#   'Libyan Arab Airlines',
#   'Ophanimon',
#   'the Liberal and Country League',
#   'Ballon',
#   'The Centralab Division of Globe Union',
#   'School of Vocal Physiology',
#   'Paris Match',
#   'Enemies',
#   'Bergamasque',
#   'Beli Dvor',
#   'British-Irish Isles',
#   'The Oklahoma City Zoo',
#   'the Melbourne Exhibition',
#   'the Russian Cavalry',
#   'The Houston Community College',
#   'Gerry & the Pacemakers',
#   'the Organisation internationale de la Francophonie',
#   'the Free Presbyterian Church of Ulster',
#   'National Highways',
#   'the Plymouth Breakwater',
#   'the First Division',
#   'JTAG',
#   'the Battle of Agincourt',
#   'the Civil Rights Movement',
#   'National Council of Nigeria',
#   'Blessed Mother',
#   'the City Parliament',
#   'Namibia Economist',
#   'the Center for Chinese Agricultural Policy',
#   "United Nations'",
#   'the Everglades National Park',
#   'Canal',
#   'Fazouro',
#   'the State of Himachal Pradesh Act 1971',
#   'Land Value Tax',
#   'Yuba Power Products',
#   '9 MetroTech Center',
#   'the World Music Awards',
#   'the Miami Central Station',
#   'The Rodeo Parade',
#   'Proto-Tethys Ocean',
#   'the New World Orchestra',
#   'AMS',
#   'Epicurus',
#   'the Centre for Cellular and Molecular Biology',
#   'Reynolds',
#   'Papacy',
#   'Yasiin Bey / Mos Def',
#   'the National Treasures of',
#   'IMP',
#   'nVidia GeForce',
#   'OPJS University',
#   'the orange loop',
#   'Alexander the Great, Lysimachus',
#   'Guinea-Bissau Creole',
#   'the Oklahoma City Community',
#   'IRFU',
#   'Yale, University College London',
#   'Latins',
#   'the Museum of Economic Geology',
#   'Scheff',
#   'Bitumount',
#   'Tumon',
#   'The Oklahoma History Center',
#   'Lysimachus',
#   'the Labour Representation Committee',
#   'Unakas',
#   'Egged',
#   'Contra Haereses',
#   'Glastonbury Tor',
#   'Shabazz Palaces',
#   'Justice',
#   'the Disaster of Yongjia',
#   'the Villa Pisani',
#   'the Baltimore Hockey Classic',
#   'Victor',
#   'the St. Louis Cardinals',
#   'AFC Ajax',
#   'the Universities of Pisa',
#   'the Raid on Drvar',
#   'San Diego Christian College',
#   'The Union League Club of',
#   'Crimes and Punishments',
#   'European Voice',
#   'Velvet Underground',
#   'the "Omni-Ingestor',
#   "Air Force's",
#   'the Communist Party Leaders',
#   'The Christian Brothers of',
#   'The German Secret Service',
#   "AC/DC's",
#   'Superama',
#   'the High Court of Tuvalu',
#   'St. Luke Penny Savings Bank',
#   'Teflon',
#   'the Palestine Liberation Organization.[citation',
#   'the Universal Charging Solution',
#   'the Origins of 9/11',
#   'Dilmun',
#   'Defense',
#   'Melinda Gates Foundation',
#   'Bannermen',
#   'OS X El Capitan',
#   'LVMH',
#   'The Music Corporation of America',
#   'Fulbright',
#   "the Crown Prince's",
#   'the Senate Committee on Small Business and Entrepreneurship',
#   'KU',
#   'the Dublin Convention',
#   'the Yale University Collection of Musical Instruments',
#   'Col de Tende',
#   'Consciousness (Chit',
#   'The Lobund Institute',
#   'the Ottoman Public Debt Administration',
#   'Pete, Nan',
#   "Maidstone United's",
#   'USMA',
#   'Universal-International',
#   'the Church of England',
#   'Tyme',
#   'the Metro AG',
#   'Musicmatch',
#   'Mainz',
#   'Northern Black Polished Ware',
#   'Pytheas of Marseilles',
#   'PBS',
#   'European Footballer',
#   'The Slavery Abolition Act',
#   'the School Hall',
#   'MIA',
#   'Cheng-Nan Expressway',
#   'the Oregon Railroad',
#   'Labour',
#   'the Greater Yellowstone Coalition',
#   'La Noce',
#   'SECAM',
#   'Haredi Judaism',
#   'Summary of Theology',
#   'Stanley Cup',
#   'Capello',
#   'Kakawira',
#   'Commerce',
#   'The Energy Policy Act',
#   'The Treasury Department',
#   'Dudok',
#   'NCIC',
#   'the Amalgamated Society of Railway Servants',
#   'Bedtime Stories',
#   'Planned Parenthood',
#   'Brent Staples',
#   'World Bank',
#   'Bells',
#   'the Stiftung Ahlers Pro Arte / Kestner Pro Arte',
#   'Spite Marriage',
#   'GTV',
#   'CM Punk',
#   'Seafair',
#   'O Tamaiti',
#   "the Church of Ireland St Patrick's",
#   'Fermi',
#   'Hindi-English College',
#   "BYU's Museum of Art",
#   'the Yale Medical School',
#   'Montreat College',
#   'Cathedral of Milan',
#   'the Western Ring Road',
#   'the Airports Authority of India',
#   'the World Federation of Exchanges',
#   'NAFTA',
#   'Samudra (Sumatra) and',
#   'Deccan',
#   'Harrapa',
#   'Timely Comics, Inc.',
#   'Harlequins Cricket Club',
#   'the Hebrew University of Jerusalem',
#   'the Brown v. Board of Education',
#   'the Wallace Line',
#   'the Belém Cultural Centre',
#   'the National Association of Basketball Coaches',
#   'Maudlin',
#   'Semitic Amorite',
#   'the U.S. Army War College',
#   'the University of Dublin',
#   'Polonic',
#   'Buckingham House',
#   'Nwankwo Kanu',
#   'Banks',
#   '/əˈdʒaɪ.ᵻjuːs/ ə-GWEE-ews',
#   'the U.S. Eighth Army',
#   'Central Intelligence',
#   'the Pure Theory of Capital',
#   'Turkish Airlines',
#   'the Church of the Nazarene',
#   'The Menninger Clinic',
#   'The Sunday Times',
#   'the General Assembly of the United Nations',
#   'the Rose Rouge',
#   'The International Monetary Fund 2010 Report on Tuvalu',
#   'Battle of Gaixia',
#   'Zwingli',
#   'Amblin Entertainment',
#   'the Kreuz-Church-Quarter',
#   'a National Historic Site of Canada',
#   'The Harvard Crimson',
#   "the Royal Naval Air Service's",
#   'Lietuvininkai',
#   'AHRA',
#   'the Armenian Apostolic Church',
#   'Health Professions',
#   'Fehling',
#   'Siddhartha',
#   'the States General (Staten-Generaal',
#   'Cosmo',
#   'Cedeira, Ferrol',
#   'Constantinople',
#   'the Council of Chalcedon',
#   'Corps',
#   'ISO 216',
#   'the Fair Expo Center',
#   'Theobromine',
#   'Warner/Chappell Music',
#   'Nomius (/ˈnoʊmiəs/ NOH-mee-əs',
#   'HapMap',
#   'the Scottish Labour Party',
#   "Coca-Cola's",
#   'the Organized Reserve Corps',
#   'the Third Fleet',
#   'Adolescents',
#   'Southern Baptist Theological Seminary',
#   'The Indira Gandhi Canal',
#   'the Joint Chiefs of Staff',
#   "Southern Army'",
#   'GST of',
#   'The Ten Great Campaigns of the Qianlong Emperor',
#   'the AFL was Arena Football',
#   'the Columbia Graphophone Company',
#   'the Bald Eagle Protection Act',
#   'The Truth About Cats & Dogs',
#   'Mexicantown International Welcome Center',
#   'Sandringham',
#   'Bryant Stratton College',
#   'Bundesverwaltungsgericht',
#   'the American Law Institute',
#   'the Jagiellonian University',
#   'the Phagmodrupa Dynasty',
#   'the Kansas Union',
#   'Woughton',
#   'Genoa',
#   'SEPTA',
#   'Fonseca',
#   'Chatto & Windus',
#   'EBS',
#   '114th Street',
#   'Regional Rail',
#   'the Kuruvungna Springs',
#   'the ICAP Securities and Derivatives Exchange',
#   'the Multilateral Fisheries Treaty',
#   'ITE',
#   'Oklahoma City Hornets',
#   'the Epistle of Barnabas',
#   'the House of Lancaster',
#   'Friedrich Hayek CH',
#   'Family',
#   'NABC',
#   'the World League of American Football',
#   'Group',
#   'MLB Network',
#   'Throgs Neck',
#   'the Cherry Creek School District',
#   "the Fishmonger's Company",
#   'The New York City Police Department',
#   'The Hugh L. Carey Tunnel',
#   'the Indo-Aryan',
#   'The U.S. Agency for International Development',
#   'Urim',
#   'The News & Observer',
#   'the Royal Bank of Scotland',
#   'Smart Cities Mission',
#   'KG 54',
#   'Records Commission',
#   'Geological Museum',
#   'the Anglo-Dutch Wars of',
#   'Palaeologi',
#   'KMC',
#   'the FIFA Club World Championship',
#   'moneylenders.:19',
#   'the Boston Herald',
#   'the Chiefs of Staff Committee',
#   'the Flaming Lips',
#   'Hendrick Motorsports, Roush Fenway Racing',
#   'the Air Raid Precautions',
#   'Swisspeace',
#   'the Pratihara Dynasty',
#   'Fram',
#   'Times Modern',
#   "Cork FM Community Radio'",
#   'Bracewell',
#   'CJK',
#   'El Grito de la Independencia',
#   'the Evanston Central Street Metra',
#   "Western Electric's",
#   'the Group of Eight',
#   'C3',
#   'Filner',
#   'United Airlines',
#   'Demoskop Weekly',
#   'the English Department',
#   'the Northam Railway Bridge',
#   'Habermas',
#   'the Indian National Army',
#   'Castello a Mare',
#   'the Butterfield Overland Mail',
#   'GPA',
#   "Imperial College Union's",
#   'Cryphonectaria parasitica',
#   'the Abbott Government',
#   'the Rivers State House of Assembly',
#   'the European Renaissance',
#   'the United Nations Development Group',
#   'Counter Terrorist Unit',
#   'the Grand Prix Americas',
#   'Control-G',
#   'Empress',
#   'Sinaloa',
#   'the National Institute of Fine Arts',
#   "the German Peasants' War",
#   'the republican Commonwealth of England',
#   'King Menelik',
#   'The Federal Railroad Police',
#   'Kinesthetic(VAK',
#   'Playhouse',
#   'the New York Jets',
#   'Deshin Skekpa',
#   'the Tyndall National Institute',
#   'the Covenant Presbyterian Church',
#   'K35DG-D 35',
#   'Windows Media Player',
#   'the Yeezy Boosts',
#   'Staats-Vlaanderen',
#   'nihari',
#   'World Energy Council',
#   'Huntingdon College',
#   'Deist',
#   'The X Factor',
#   'Standard Oil of',
#   'Medicare',
#   'The Washington Post',
#   'the United Nations Convention on the Law of the Sea',
#   "The Bellamy Brothers'",
#   'the United Nations Conference on Trade and Development',
#   'Ryan Airlines',
#   'Dixie State University',
#   'DHT',
#   'the Society of American Indians',
#   'Directive 94/33/EC',
#   'the García Torres Foundation',
#   'HMS Jamaica',
#   'the Stephen Lawrence Prize',
#   'the Cathedral of Saint-Jean at Lyon',
#   'Wodziński',
#   'Jonassohn',
#   'Fletcher Christian',
#   'Illinois Fighting Illini',
#   'The Canadian Armed Forces',
#   'HMV',
#   'Arab League',
#   'Classical Mandolin Society of America',
#   'Sky 3D',
#   'the Connecticut Tennis Center',
#   'Private Office',
#   'Bachelor of Arts',
#   'Contemporary Performing Arts',
#   'the Mongol Yuan',
#   'United States Air Force',
#   'the Armed Forces of the Philippines',
#   'Homo',
#   'Administracion Nacional de Puertos',
#   'Fagan',
#   'the Periadriatic Seam',
#   'Aesthetic Group Gymnastics',
#   'the Great St. Bernard Pass',
#   'SI watts',
#   'TB',
#   'the Anglo-Welsh',
#   'Wellington College',
#   'Royal College of Art',
#   'Santa Fe de Nuevo México',
#   'Boston Symphony Hall',
#   'Development Testing',
#   'DTR/DIS',
#   'Universal Pictures',
#   'the Hotel Bristol',
#   'Neighbours, Kath & Kim',
#   'Les Wexner',
#   'BA',
#   'NCB',
#   'Sicis The Art Mosaic Factory Srl',
#   'Community Health Center',
#   'the University of Hawaii',
#   'avian species',
#   'Jamahiriyah',
#   'Continental news',
#   'the Constitutional Convention',
#   'Turner Home Entertainment',
#   "Safdarjung's Tomb",
#   'Tilbury',
#   "St. John's University",
#   'Modern Chemistry',
#   'Global Engagement Summer Institute',
#   'Procyon',
#   'the High Sheriffs for',
#   'Temperate Prairies',
#   'the Southern Xiongnu',
#   'United States Department of Defense',
#   'Vostok 5',
#   'Special Air Service',
#   'the New Haven Historic Commission',
#   'the Japan Broadcasting Corporation',
#   'the Tredegar Iron Works',
#   'The House Jacks',
#   "Jean-Baptiste Wicar's",
#   'the Senate Committee on Commerce',
#   'The United States Census Bureau',
#   'the Asty Films Company',
#   'Northwest Division',
#   'Southampton Container Terminals',
#   'the First Temple',
#   'the University Culture Center',
#   'electro house',
#   "St. Louis Children's Hospital",
#   'the Lodge of Edinburgh',
#   'Cyrtonyx',
#   'Digital Rights Management',
#   'Addison Streets',
#   'Terminal 2',
#   'The Hyderabad Metro',
#   '0.5–2 m/s',
#   'the Central Public Works Department',
#   'the English Church',
#   'the Water Tribunal of Valencia',
#   'EUCLID',
#   'Oldham, Preston',
#   'FC Pyunik',
#   'Vojvođani',
#   'All Progressives Congress',
#   'the Revolutionary Étude',
#   'the Spectacled Petrel',
#   'Red Sox',
#   'Directive on Renewable Energy',
#   'American Assembly',
#   'The Multidimensional Pain Inventory',
#   'Resident',
#   'the Canadian Forces Health Services Group',
#   'World University Rankings',
#   'Technion-Israel Institute of Technology',
#   'the Fisher Theatre',
#   'the Manchu Bannermen',
#   'Diplura',
#   'Alexander Bell',
#   'Wells',
#   'Neo-Platonism',
#   "All Japan Women's Pro-Wrestling",
#   'the Bristol Trade School',
#   'redd hede',
#   'Mercedes-Benz Fashion',
#   'iPhones',
#   'University College School',
#   'Off-Off-Broadway',
#   'The Métropole du Grand Paris',
#   'Lakecrest Independent',
#   'Unaka Front',
#   'Malampa',
#   'Gandzak',
#   'Maréchaussée',
#   'Littel',
#   'the Court of Appeal',
#   'Deutsche Grammophon',
#   'Honey',
#   'the Cadet Instructors Cadre',
#   'Complex',
#   'BBC Worldwide',
#   'Intelsat 7',
#   'the Western Electric Wide Range System',
#   'the Oklahoma Heart Hospital',
#   'XHJK-TDT 27',
#   'Sharron Davies',
#   'Power',
#   "Publication of Ferdinand de Saussure's",
#   'Rheji Burrell & Rhano Burrell',
#   '601st Antiaircraft Gun Battalions',
#   'the British Broadcasting Corporation',
#   'Secure Communities',
#   'Marine Engineering',
#   'the Carnival Studio Theater',
#   'Tower Hamlets College',
#   'Paideia',
#   'GameSpot',
#   'UMI',
#   'Yale College',
#   'the Optical Disc Corporation',
#   'NBCSN',
#   'Memorial University of Newfoundland',
#   'FC Porto',
#   'the Melville J. Herskovits Library of African Studies',
#   'Latin Church',
#   'the National Memorial Cemetery',
#   'the Papal Residence Castel Gandolfo',
#   'US Court of International Trade',
#   'The Houston Air Route Traffic Control Center',
#   '3rd Battalion',
#   'Introduction',
#   'Oudh',
#   'the Western Division',
#   'Letters, Science, Engineering, Business',
#   'ITO',
#   'Rems-Murr-Kreis',
#   'Yildiz Technical University',
#   'Easter Holidays',
#   'the Television Newsreel',
#   'LL Cool J',
#   'Greenbank',
#   'CATV',
#   'the Houston Press',
#   'the Ministry of Internal Affairs',
#   'Spanish League',
#   'the Museum for African Art',
#   'The Crown Dependencies',
#   'Federal Government Future Fund',
#   'Tian Shan',
#   'Houses',
#   'Arrhenius',
#   'the Caves of Nanumanga',
#   'IGY',
#   'the Los Angeles County Bicycle Coalition',
#   'Turkic',
#   'New Haven Advocate',
#   'CEM-3',
#   'Graeco-Roman',
#   'the New York City Recruiting Battalion',
#   'The Estació del Nord',
#   'Entertainment Weekly',
#   'LAA',
#   'Daimler',
#   'the Bois de Vincennes',
#   'NBA Playoffs',
#   'the Philadelphia City Council',
#   'Renton',
#   'Istvaeonic (Weser-Rhine Germanic',
#   'Ninggao Intercity Line',
#   'USAF Air Demonstration',
#   'Abbasid',
#   'Ingvaeonic',
#   'Tantra',
#   'the Rome Laboratory',
#   'Modern Estonia',
#   'the Ukrainian Cultural Club',
#   'the Kanye West Foundation',
#   'Indiamen',
#   'Blue Flare',
#   'The University of Berlin',
#   'German Reich',
#   'Lotus Notes',
#   'the Office of Trade',
#   'the Marine Biological Association',
#   'the NASCAR Hall of Fame',
#   'Institute of Himalayan Bioresource Technology',
#   "the USA PATRIOT Act's",
#   'Sophronios',
#   'Rainbow',
#   'the Swiss Confederation',
#   'Battersea Dogs Home',
#   'Estophile',
#   'the Seattle Chamber Music Society',
#   'T3a',
#   'Sultanates',
#   'VMware Fusion',
#   'the White Stockings',
#   'VHF',
#   'Sega Enterprises',
#   'Sophronius of Jerusalem',
#   'the Light Brigade',
#   'the University of Birmingham',
#   'the Islamic Center of Virginia',
#   'SABRE',
#   'Operation Rolling Thunder',
#   'the Simplon Tunnel',
#   'Ceauşescu',
#   'the Andhra Saraswata Parishad',
#   "the Baseball Writers' Association of America",
#   'Christian AC',
#   'RIBA Insight',
#   'The Genome Center',
#   'BIOS ROM',
#   'Les Corts',
#   'al-Kindi',
#   'Brixton',
#   'Abgeordnetenhaus',
#   'HM Treasury',
#   'the Central American Free Trade Agreement.[citation',
#   'the Bascom Affair',
#   'the Weapons Station',
#   'the Association of University Technology Managers',
#   'Antarctic',
#   'The Museum of Contemporary Art San Diego',
#   'the Duchy of Aquitaine',
#   'WSND-FM',
#   '40th Divisions',
#   'RMI',
#   'BWRSDF',
#   'the Institute of National Remembrance',
#   'Agreement on Trade-Related Aspects of Intellectual Property Rights',
#   'Hotel Pierrepont',
#   'Table Football',
#   'Malika-i-Mauseequi (Queen of Music',
#   'Roanoke',
#   'Oltenia',
#   'Pan American World Airways',
#   'Callimachus',
#   'the Bancaria Jazz Club',
#   'Royal Dutch Shell plc',
#   'Metrodorus of Scepsis',
#   'Mack Newton',
#   'the U.S. Treasury',
#   'NYSE',
#   'Ariel University',
#   'e.g. CATOBAR or',
#   'Febvrier Despointes',
#   'Comcast Center',
#   'Teddington Lock',
#   'Feeder and Stereophonics',
#   'TsUM',
#   'the Omnibus Crime Control',
#   'Rehabilitation',
#   'Jew',
#   'nicosulfuron',
#   'Hanuman Dhoka',
#   'WDAS',
#   'The National History Museum of Montevideo',
#   'Phantom Hourglass',
#   'The City Island Historical Society and Nautical Museum',
#   'Greater Boston',
#   'the Institute of Public Enterprise',
#   'National League for Democracy (NLD',
#   'Monsanto',
#   'Eusébio',
#   "Ishida Mitsunari's",
#   'the New World Translation',
#   'The Times',
#   'The Richmond Mural Project',
#   'Motörhead',
#   'RFU Championship club',
#   'the P-N',
#   'Bas-Rhin',
#   'Supreme Allied',
#   "Beck's",
#   'Partner Program',
#   'the First Great Awakening',
#   'the Command/Service Module Columbia',
#   'MGM/UA Communications Co.',
#   'Capricorn Technologies',
#   'Nomios',
#   'the Sister Cities Plaza',
#   'Bardufoss Air Station',
#   'Command Module Pilot',
#   "Canute's Palace",
#   'Western World',
#   'MacArthur Causeway',
#   'the Emil Verban Society',
#   'Sweet Inspiration',
#   'Detroit Pistons',
#   'Altay Sports Club',
#   'Division II',
#   'Mateos International Airport',
#   'WarPac',
#   'Apple II',
#   'Elatus',
#   'the Shenzhen Stock Exchange',
#   'Northeast Detroit',
#   'the Teatro Solís',
#   "Olin Corporation's",
#   'Best R&B Song',
#   'Ninhursag',
#   'the Meiji Era',
#   'Brasileirão',
#   'the Community Charge',
#   'Reggie Lucas',
#   'Princeton University Chapel',
#   'Macintosh Office',
#   'the BBC Trust’s Editorial Standards Committee',
#   'the Partitions of Poland',
#   'C57H110O6',
#   'Chemistry',
#   'CBS Corporation',
#   'Ficus',
#   'the Grand Lodge of England',
#   'Jamahiriya',
#   'BlueRay',
#   'the "Union of Myanmar',
#   'The Museum of Peoples and Cultures',
#   'Moore',
#   'The Census',
#   'the American Assembly',
#   'EMI/Capitol Records',
#   'Dwyer',
#   'Sea Cat',
#   'the Statute of Westminster 1931',
#   'The Hypogeum of Ħal-Saflieni',
#   'stereophonic sound',
#   'EMI',
#   'The Aesthetics of Comics',
#   'Centrelink and Medicare',
#   'the Franks Casket',
#   'Napoleon-Bonaparte First Consul for Life',
#   'The Seattle Post-Intelligencer',
#   'the Museum of Decorative Arts of Montevideo',
#   'Throgs Neck Bridge',
#   'Canal de la Marne',
#   'Deccan Suba',
#   'The Midtown Raleigh Alliance',
#   'the Greek Orthodox Church',
#   ...],
#  'DATE': ['the mid 5th century',
#   '1 September 1961',
#   'November 1820',
#   'the early decades',
#   'another year',
#   '21 March–21 June 1952',
#   '17 days',
#   'Nine days later',
#   '1970 to 1974',
#   'the Capetian dynasty',
#   'about 1600',
#   '8 May 1899',
#   'the mid 1970s',
#   'Between 1965 and 1981',
#   'the 4th century AD',
#   'the last year',
#   '6 June 1963',
#   'around 50 days',
#   'the most recent year',
#   'the 3rd quarter of 2007',
#   'May 21, 2008',
#   '23456789-',
#   'Between 1791 and 1833',
#   '1449',
#   'five more years',
#   '7 September',
#   'September of that year',
#   'October 15 of that year',
#   'at least 50 years',
#   'Around 1450',
#   '19 November',
#   '10–6 3.82',
#   'The past century',
#   'March 30, 2015',
#   'December 5, 2015',
#   'From 1945 to 1948',
#   'October 1969',
#   '1911',
#   'each summer',
#   '2600 era',
#   '30 November',
#   'before the end of',
#   'the end of the Mesozoic',
#   'January 1661',
#   '430 years',
#   '26 February',
#   '1714',
#   'mid-1941',
#   'the late 18th',
#   '1295',
#   '14 to 18',
#   'late October 1950',
#   'the first hundred years',
#   '132 AD',
#   'two years ago',
#   'February 26, 1987',
#   'January 18, 1940',
#   'June 1944',
#   '29 December',
#   '1719',
#   '7 days',
#   'January 27, 2013',
#   'the spring of 1943',
#   'season ten',
#   "June 1985's",
#   '1981',
#   'January to June',
#   '1274',
#   'early adolescent years',
#   'Two days earlier',
#   '1813',
#   '26 to 30 days',
#   '44 years',
#   'June 6',
#   '4 December 2013',
#   'the beginning of February',
#   'mid-1850s',
#   '5150',
#   '26 March 1969',
#   'August 1870',
#   '3 July 2005',
#   'the 16th to 18th centuries',
#   'April 15',
#   '1515',
#   '15–64 years old',
#   '19–31 August 1855',
#   'widescreen 16:9',
#   'Almost a year',
#   'many decades',
#   'the Bourbon Dynasty',
#   'late July 2011',
#   '1929 to 1943',
#   '18th century',
#   '11 March 1978',
#   'February 1835',
#   'October 2004',
#   '40 years',
#   'another decade',
#   '30 March',
#   'between 1908 and 1925',
#   '17 March 1691',
#   'the next decade',
#   'a century later',
#   'the end of the first decade',
#   '653,556',
#   '2003 to',
#   '30 March 1930',
#   'between 3600 and',
#   'about the 9th century',
#   'July 2',
#   'around 1090',
#   'the end of the month',
#   'Summer 2014',
#   'the early 1880s',
#   '26 July 1840',
#   'a century earlier',
#   'April 1826',
#   '5 May 1855',
#   'the Sui Dynasty',
#   'three or four days',
#   'August 1987',
#   '25 October 1922',
#   'the nine days',
#   '27 May 1860',
#   '1216',
#   'nearly two years',
#   'May 1959',
#   'September 2, 2014',
#   'a hundred years',
#   '13 October 2009',
#   'March 16, 2012',
#   'the Spartocid dynasty',
#   '1122',
#   '8 March',
#   'November 1998',
#   'December 1',
#   '3629',
#   'The 1980s',
#   '10 May 1861',
#   'April 23',
#   'January–April',
#   'mid-19th century',
#   'August 1560',
#   '3 January 1941',
#   'October 1970',
#   'around the 7th century AD',
#   'age 20',
#   'October 25, 2005',
#   'the first quarter of 2014',
#   'a few centuries',
#   'the 1st',
#   '26 April 1882',
#   'four centuries',
#   'about 1982',
#   'two solid weeks',
#   '16 years',
#   '1102',
#   '17 October 1956',
#   'late September 2009',
#   '2001 to 2010',
#   '20 August 1991',
#   'the 2015',
#   'the early 9th century',
#   'April 2013',
#   'Today',
#   'November 7, 2006',
#   '27',
#   'April 18, 1780',
#   '1724–1804',
#   '23 May 1984',
#   'the Day of Resurrection',
#   'The years',
#   '22 February 1983',
#   '1589',
#   '365.24219 days',
#   'post-1985',
#   'June 19, 1968',
#   'the end of the 4th century',
#   '30s',
#   '2005',
#   'the first five seasons',
#   '1635',
#   '17 November 1989',
#   'Some days',
#   'September 2, 1992',
#   'summer, winter',
#   'age 4 to 11',
#   'the teenage years',
#   'about 1137',
#   'over 30 years',
#   'mid 1st century',
#   '1 year',
#   '1985–2015',
#   'May 1892[nb 1',
#   'August 3 to 8, 1931',
#   'The next week',
#   'West Indian Day Carnival',
#   'January 1773',
#   '26 December 2007',
#   '1793',
#   'Monday',
#   '1809 to',
#   'September 21, 1997',
#   'January first of every year',
#   'between mid-1974 and 1977',
#   'between 1961 and 1968',
#   'a Long March',
#   'seven years earlier',
#   '2 August 1921',
#   'Labour Day',
#   'the mid-fifteenth century',
#   'mid-1877',
#   '13 March 2015',
#   'the 1850s',
#   'another two seasons',
#   'October 1972',
#   'the winter of 1978–79',
#   'the first decades of the 19th century',
#   'a rainy season',
#   'at least thirty years',
#   '1540-1542',
#   '6 August 1945',
#   'November 1975',
#   '9,000 years ago',
#   '2000s',
#   '1438',
#   '6 February 1941',
#   'May 16, 2011',
#   'June 2013 – June 2014',
#   'mid-2011',
#   'the 14th-century',
#   '44 days',
#   '2 or 3 nights',
#   'April 18, 1985',
#   'first week of September',
#   'the first full season',
#   'the end of the Rigvedic period',
#   'the half century',
#   'July 1942',
#   'the early to mid-90s',
#   'the present century',
#   '1279',
#   '15 May 2014',
#   '59',
#   '4 years',
#   'September 24, 2003',
#   'December 11, 2012',
#   'the past 50 years',
#   '3-year-old',
#   'fiscal quarter 4 of year 2008',
#   'Several days later',
#   'the mid-1700s to the 2000s',
#   'Fall 2008',
#   'January 1, 2000',
#   '182–252 AD',
#   'West 27th Street',
#   '17 May 2015',
#   'this season',
#   '1879',
#   'June 12, 1880',
#   'R1a1a7',
#   '30 August 1835',
#   '1849',
#   'several years in a row',
#   '00',
#   'a decade before',
#   'the tenth through twelfth seasons',
#   'the third year',
#   'January 1952',
#   'between 2050 and 2070',
#   '1328',
# ...
#   '4,095 metres',
#   '3,000-mile',
#   '230 kg',
#   '44-million-gallon',
#   'less than 20 mm',
#   '10,676 mi',
#   '190 km',
#   '78 degrees',
#   '148 km',
#   '518 sq mi',
#   '210 sq mi',
#   '53,500 square metres',
#   '423 km',
#   '1.2×1010 cu ft',
#   '174,000 terawatts',
#   '4.0 mi',
#   '287 kilometres',
#   '4,500 kg',
#   '30 to 50 inches',
#   '1,250 millimetres',
#   '49-xxxx',
#   '50–100 miles',
#   '1,500 yards',
#   '2,743 sq mi',
#   '8-acre',
#   '8.0–16.1 km',
#   '10,663 km',
#   '727 mm',
#   'several hundred 7 inch',
#   '75 ppm',
#   'approximately 2.4 billion',
#   'several modules',
#   '3,900,000 long tons',
#   '5 ft',
#   '1,100 square miles',
#   '15,000 kilometres',
#   '166 billion barrels',
#   '3.5-mile',
#   '980 feet',
#   '9,000 km',
#   '409.8 feet',
#   'over 1 million barrels',
#   '14 kg',
#   '56 km',
#   '3.38 kilometres',
#   '420 tonnes',
#   '500 short tons',
#   '15 million tonnes',
#   '45 km',
#   '25,000 to 45,000 tonnes',
#   'nautical-mile',
#   'a few miles',
#   'only 356 mm',
#   '15 inches',
#   '165 cm',
#   '1,999 feet',
#   '3,794 kilometres',
#   '24 kV.',
#   'less than 300 feet',
#   '100,000 ton',
#   'Five tons',
#   '614 mm',
#   '4,000 yards',
#   '267.8 kg',
#   '160 ton',
#   '364,000 square feet',
#   'two degrees',
#   '2,800 m2',
#   '21.7 feet',
#   '3.2 km',
#   '21 metres',
#   'a few hundred feet',
#   '112,934 tonnes',
#   'one-kilometre',
#   '136 mm',
#   '468.9 square miles',
#   ...],
#  'PERCENT': ['0.09% to 0.25%',
#   '14.1%',
#   'almost 50%',
#   'more than 95%',
#   'over 35%',
#   'another 10% to 30%',
#   '0.6 percent',
#   '57.4%',
#   '12.3%',
#   'only eight percent',
#   '69%',
#   'only 1 percent',
#   'around 7%',
#   '63.9%',
#   'another 12.7%',
#   'about 22%',
#   '51.5%',
#   '1.3%',
#   'only 36 percent',
#   '85.6%',
#   'about 42%',
#   '97.3%',
#   '6.6%',
#   'about 77%',
#   '51.2%',
#   '12.6%',
#   'about 16%',
#   'an estimated',
#   '3.38%',
#   'roughly 7%',
#   'only 2.5 percent',
#   '19 percent',
#   'nearly 92%',
#   '11.0%',
#   'about 10.6%',
#   '18%',
#   '10.9 percent',
#   '0.70%',
#   '5–95%',
#   '43.1%',
#   '37.83%',
#   '99 percent',
#   '2.06 percent',
#   '54.0%',
#   'five percent',
#   'Approximately 10%',
#   'only 22%',
#   '95.6%',
#   '15–20%',
#   'Fifty-six percent',
#   'only 14%',
#   '40–60%',
#   'about 10%',
#   'less than 10%',
#   '10-45%',
#   '17.7%',
#   'About 2%',
#   'about 12 percent',
#   'about 5%',
#   '64.5%',
#   'the 79%',
#   '43% to 13%',
#   'an estimated 6%',
#   '3.25%',
#   '8.8 percent',
#   '3.0% to 5.0%',
#   'roughly fifty percent',
#   'about 85%',
#   '91 percent',
#   '1.88%',
#   '90 percent',
#   'around 8%',
#   '67.02%',
#   '2.6%',
#   '98%',
#   '16–21%',
#   '43%-46%',
#   'more than 66 percent',
#   '98.1%',
#   '0.06%',
#   '84.8%',
#   '21.4 percent',
#   '4.65%',
#   '13.76%',
#   '50.1 percent',
#   '19.9%',
#   '38 percent',
#   'Forty percent',
#   '16.1%',
#   'over 60 percent',
#   '42.4 percent',
#   '10.2 percent',
#   '~13.5%',
#   '49%',
#   '84.2%',
#   'about 65%',
#   '10.1 percent',
#   '11.7%',
#   'Less than 1%',
#   '14.03%',
#   'More than 60%',
#   '5–25%',
#   '0.4%',
#   '13.5%',
#   '29.5%',
#   '3% to 4%',
#   '85%',
#   'an estimated 60%',
#   'Approximately 37%',
#   'more than 20%',
#   '33% to 18%',
#   'only 5%',
#   '8.8%',
#   '5-10%',
#   'about 8%',
#   '0.56%',
#   'around 9%',
#   '23%',
#   '5.0 percent',
#   'almost 90%',
#   'roughly 60 percent',
#   'another 70.2%',
#   '78.29%',
#   '70.4%',
#   '96.2%',
#   '29.0%',
#   '23.02%',
#   'About 69%',
#   '2.1 percent',
#   '34.1 percent',
#   'around 50%',
#   'Between 60,000(4%',
#   'Twenty-five percent',
#   '5% to 36%',
#   '83 percent',
#   '15%',
#   '56%',
#   '9.27%',
#   'over six hundred thousand dollars',
#   '7.2%',
#   '24.6%',
#   '68%',
#   'As much as 90 per cent',
#   'only 14.21%',
#   '66.7%',
#   '85.0%',
#   '8.3%',
#   '15.1%',
#   '22.5 percent',
#   '12–13%',
#   '42.6%',
#   '85–88%',
#   '400%',
#   '1.7 percent',
#   '50–90%',
#   '63.31%',
#   '13.6 percent',
#   'only 6.1%',
#   'only about 1.2%',
#   '8–10%',
#   '5.7%',
#   'Over 85 percent',
#   'about 3.5%',
#   'some 58%',
#   'Approximately 58.2%',
#   '0.52%',
#   '21.9%',
#   '14.3%',
#   '10.4%',
#   '3.02 percent',
#   'only 28.3%',
#   '27.9 percent',
#   'more than 17%',
#   '1.0%',
#   '6.9%',
#   'about 1.8%',
#   'about 41–43%',
#   'over 75%',
#   '1.22%',
#   'about 12%',
#   'over 90%',
#   '44%',
#   '0.25% to 0.40%',
#   'Eighty-two percent',
#   '8%',
#   '1.16%',
#   '5.97%',
#   '52.1%',
#   'nine percent',
#   'around 17 percent',
#   'about 49%',
#   '13.6%',
#   '0.4 percent',
#   '75.70%',
#   '37.5%',
#   '22.7%',
#   '14.4%',
#   '52.66%',
#   'About 23.1%',
#   'most 40%',
#   '24%',
#   'around 28%',
#   '6 to 10%',
#   '8 percent',
#   'about 70%',
#   '30.69%',
#   '63 percent',
#   '10% to 13%',
#   'nearly 82 percent',
#   'up to 45%',
#   'at least 70%',
#   '96.7 percent',
#   '21%',
#   '45%',
#   '47%',
#   '48%',
#   '0.28%',
#   '63.5%',
#   'only 19.1%',
#   '20.7%',
#   '57%',
#   '36.92%',
#   '39.2%',
#   '32%',
#   'Some 97 percent',
#   '70 to 74%',
#   '23.8 percent',
#   'more than 55%',
#   'approximately 42–48%',
#   'Less than 1 percent',
#   '20.4%',
#   'more than 12%',
#   '5.8%',
#   'over 12.5%',
#   'about 12.72%',
#   '47.2%',
#   '81.0%',
#   '8–16%',
#   'Some 60 percent',
#   'no more than 30%',
#   '99.94 percent',
#   '7.1%',
#   '98.77 percent',
#   '14%',
#   '79.79%',
#   '1.2%',
#   '80.51%',
#   'less than 20%',
#   '6.5 percent',
#   '18.4%',
#   'only 3–4%',
#   'An estimated 40%',
#   '27 percent',
#   'about 2.0%',
#   '70% to 80%',
#   '69.7%',
#   '2.88 percent',
#   '6.75 percent',
#   '8.7%',
#   '0.45%',
#   '38.29%',
#   '23.2%',
#   '27.0 percent',
#   '27.4%',
#   '17.2%',
#   '67.4%',
#   '24.95%',
#   '10 percent to 40 percent',
#   '2.5 percent',
#   '11.4%',
#   '99.2742%',
#   '17%',
#   '32 percent',
#   'More than 90%',
#   'only 3%',
#   '22-23%',
#   '11.80%',
#   '22–25 percent',
#   'just 18%',
#   '15% to 35%',
#   '0.90%',
#   '3.1 percent',
#   '1.4 percent',
#   'Nine percent',
#   'up to 10%',
#   '49% to 22%',
#   '9.6%',
#   '2.75%',
#   '0.5 percent',
#   '28.8%',
#   'Nearly 60%',
#   '3.92%',
#   '2–8%',
#   '3–10%',
#   '6.4 percent',
#   '41.0%',
#   '89.5 percent',
#   'no more than 20%',
#   'around 43%',
#   '8.5%',
#   'only 8 percent',
#   'as high as 70%',
#   '4.1 percent',
#   '47.5%',
#   '0.36%',
#   'about 4%',
#   'over 200%',
#   '49.3%',
#   'the 33%',
#   '90% to 95%',
#   '11 percent',
#   '67.7%',
#   '78.7%',
#   '4.1%',
#   'nearly 100%',
#   'Only 35%',
#   '0.9%',
#   'Seventy-five percent',
#   '2.76%',
#   '68.1%',
#   'approximately 13%',
#   'only 9.5%',
#   'the 51%',
#   '34.4%',
#   'more than 20 percent',
#   '64 percent',
#   '104%',
#   'twenty-five percent',
#   '16.4%',
#   '7.3%',
#   '4% to 16%',
#   'less than 1% to 13%',
#   '14.5%',
#   '22.3%',
#   'Only 61%',
#   '52.5%',
#   '90–95%',
#   'Another 12%',
#   'an estimated 90%',
#   '50.3%',
#   '48 percent',
#   '53.8%',
#   '4.3%',
#   '26.68%',
#   '18.5%',
#   '38.8%',
#   '0.20%',
#   '27.80%',
#   '16.45%',
#   'up to 37 percent',
#   '16.0%',
#   '29%',
#   '79.12%',
#   'only 20.8%',
#   '79.0%',
#   'about 3.1%',
#   'the remaining 75%',
#   '1.12%',
#   'around 2.0%',
#   'roughly 28–37%',
#   '16.50%',
#   'no more than 5 °C',
#   'approximately 3%',
#   'around 45%',
#   'as far as',
#   'between 20% and 25%',
#   'the remaining 31%',
#   'about 2%',
#   '39.52%',
#   'at least 10%',
#   '1.23%',
#   '60–70%',
#   '33.8%',
#   'only around 2%',
#   'almost 15%',
#   '36.7%',
#   '6% to 15%',
#   'About 3.72%',
#   'around 6 percent',
#   'approximately 47 percent',
#   '7.9%',
#   '2.62%',
#   'about 6.11%',
#   'about 1.5%',
#   'an estimated 80%',
#   '30-32%',
#   '98.8%',
#   '99.9%',
#   'Over 50%',
#   "7'E and 8°30'S.",
#   '20.2%',
#   'nearly 25%',
#   '0.44%',
#   '21.4%',
#   'around 2.38%',
#   '45.3%',
#   'about 69%',
#   '55%',
#   '0.7%',
#   '80.4%',
#   '11.35%',
#   'seventy percent',
#   '14.7%',
#   '17.6%',
#   '58 percent',
#   '14.6%',
#   'only 12.6 percent',
#   '4.82%',
#   'nearly 10 percent',
#   '23.9%',
#   '100 percent',
#   '9 percent',
#   '7.5%',
#   'roughly 3%',
#   '20.6%',
#   '31 percent',
#   'An estimated seventy percent',
#   '57.6%',
#   '82.8%',
#   '16.8%',
#   '0.47%',
#   'about ten percent',
#   '3.75%',
#   '27.9%',
#   'only about 37%',
#   '64.8%',
#   '171%',
#   '0.002%',
#   'more than 40 percent',
#   'as much as 10%',
#   'Approximately 87%–95%',
#   'about 59%',
#   '42 percent',
#   'approximately 69%',
#   '15.5%',
#   '27.1%',
#   'about 5 percent',
#   '12.08%',
#   'less than 6%',
#   '62.3%',
#   '46.2%',
#   'as much as 70%',
#   'about 72%',
#   '0.8%',
#   '99.7%',
#   '2.8%',
#   'over 99%',
#   'only 10 percent',
#   '7.57%',
#   '7.4%',
#   '36.2%',
#   'between 99% and 100%',
#   'approximately 13.1%',
#   '4.2%',
#   '88 percent',
#   'over 9%',
#   'around 7–10%',
#   '96.5%',
#   '45.1%',
#   'two percent',
#   'approximately 45%',
#   'only 2.5%',
#   'approximately five percent',
#   '0.15%',
#   '96.91%',
#   '78.5%',
#   'About 80%',
#   '80.6 percent',
#   'only one percent',
#   '74.04%',
#   'only 62.5%',
#   '50.6%',
#   'Roughly 4%',
#   'about 50%',
#   '13.8%',
#   '24–27%',
#   '58.1%',
#   '61 percent',
#   'another 61%',
#   '21.8%',
#   '44.02%',
#   'about 0.6%',
#   'About 92%',
#   'about 10%–15%',
#   '6–8%',
#   'Approximately 10 percent',
#   'about 26%',
#   '95 percent',
#   'roughly 9 percent to',
#   '54%',
#   'nearly 80%',
#   'just 28 percent',
#   '1.4%',
#   '0.0%',
#   'More than 99 percent',
#   'about 71%',
#   '4 percent',
#   'more than 93%',
#   'only 18%',
#   '47 percent',
#   '72 percent',
#   'up to 55%',
#   'between 16–52%',
#   '1% to 11%',
#   '15.7 percent',
#   '12%',
#   '±20%',
#   '28.5%',
#   '98.4%',
#   '40.16%',
#   '44.8%',
#   '15.7%',
#   '89%',
#   '5%',
#   'three percent',
#   '1.1%',
#   '69.5%',
#   '40-50%',
#   'about 40%',
#   'nearly 40 percent',
#   '6.88 percent',
#   '0.98 percent',
#   '3.1%',
#   '78 percent',
#   'less than 100%',
#   'about 20%',
#   '21.7%',
#   'almost 100%',
#   'only around 5%',
#   '35.5%',
#   'between 4% and 75%',
#   '11.5%',
#   '41 percent',
#   '89 percent',
#   'eight percent',
#   '113%',
#   '16.9%',
#   'more than 99.5%',
#   '170 percent',
#   '49.8%',
#   '59%',
#   'up to 90%',
#   '3.74%',
#   'as much as 85%',
#   '94.7%',
#   '7.9 percent',
#   '36.5%',
#   '61.9%',
#   'Approximately 70%',
#   '66%',
#   '15% – 30%',
#   'approximately 35%',
#   'almost 80%',
#   '0.6%',
#   'just about 15%',
#   'over 80 percent',
#   'only 34 percent',
#   '17.8%',
#   'as much as half',
#   '27%',
#   '62.89%',
#   'close to 100 percent',
#   '0.2%',
#   'between 21.6–30%',
#   '43%',
#   'about 7%',
#   '89.8%',
#   'approximately 25%',
#   '88.7%',
#   '13.44%',
#   'Nearly 47%',
#   '21.5%',
#   '9.7%',
#   '54.8%',
#   '0.1–2.5%',
#   '66% to 96%',
#   '1 percent',
#   '60–80%',
#   '45 percent',
#   '87.8 percent',
#   '26.9%',
#   'more than five percent',
#   '54.7%',
#   '52.3%',
#   '4.7%',
#   '172%',
#   '85.2 percent',
#   'the remaining 5%',
#   '1–3%',
#   '5.3%',
#   'only 1.9%',
#   '16 percent',
#   '98.56 percent',
#   '10.6±2.1 Hz',
#   'more than 37 percent',
#   '34%',
#   'between 60–70%',
#   '3.09%',
#   '33.9%',
#   '3.4 percent',
#   '52.6%',
#   'seventy-five percent',
#   '24.3%',
#   '20–25%',
#   '58.6%',
#   'approximately 75%',
#   'More than 20%',
#   'this only 13%',
#   '340%',
#   'that 90%',
#   '23.5%',
#   '56.0%',
#   '51 percent',
#   '24.86 percent',
#   '85.96%',
#   '17 percent',
#   '99%',
#   'about 99%',
#   '1.5% to 5.8%',
#   '41.4%',
#   '13.9%',
#   '33.6%',
#   'about 83%',
#   'as high as 89%',
#   'Approximately 75%',
#   '15 percent',
#   '34 percent',
#   '80.2%',
#   'About 60 percent',
#   '4.41%',
#   '6.8%',
#   'as much as',
#   '3.6%',
#   '6.9 percent',
#   '0.55%',
#   'about 17%',
#   '23 percent',
#   '42.0%',
#   '84 percent',
#   '0.0054%',
#   'about 5% to 10%',
#   '22%',
#   'just 7.6%',
#   '56.1% to 61.5%',
#   '11.86%',
#   '9.13 percent',
#   '12–20%',
#   '45.6%',
#   '12.7 percent',
#   '8.5 percent',
#   '33.0%',
#   'over 91%',
#   '51.7%',
#   '10.5 percent',
#   '50.09%',
#   '92.4%',
#   '3.9%',
#   '82%',
#   '25.6%',
#   'approximately 90% to 96%',
#   '60 to 70%',
#   '29.6%',
#   'About 16%',
#   '14 to 38 percent',
#   '85–90%',
#   'About 25%',
#   '24.2%',
#   'About 19.1%',
#   'Approximately 51 percent',
#   '0.25%',
#   '4.0%',
#   'about 60%',
#   'an average 49.1%',
#   '49.4%',
#   '30%',
#   '15.02%',
#   'Over 80%',
#   '52.0%',
#   'about 48 percent',
#   '40–70%',
#   '53.5%',
#   '0.5%',
#   'barely 2%',
#   '−5.5%',
#   'Around 90%',
#   '23% to 56%',
#   '52 percent',
#   '75%',
#   '18.8%',
#   '75 percent',
#   '40.6%',
#   'almost 45%',
#   '9.8%',
#   '37.2%',
#   '24.4%',
#   '79%',
#   '1.4% to',
#   '22–27%',
#   '77.4%',
#   '10.2%',
#   'about 31%',
#   '30.8%',
#   '2.4%',
#   '95.1%',
#   '69.6%',
#   'up to 60%',
#   '7.6%',
#   '25.7%',
#   '45.5 percent',
#   '0.47 percent',
#   'about 6 percent',
#   '2.9 percent',
#   '1.6%',
#   'over 45%',
#   '0.11%',
#   '78%',
#   '15.3 percent',
#   '0.7204%',
#   'only 40%',
#   '4.5–6%',
#   '61% to 69%',
#   '75.9%',
#   '17.4%',
#   '24.7%',
#   '3.17%',
#   '54.78%',
#   '70-80%',
#   'just under 50%',
#   '84%',
#   '99.16 percent',
#   'More than 95%',
#   '1.9 percent',
#   '22.6%',
#   '48.8 percent',
#   '22 percent',
#   '5.2%',
#   'only 15%',
#   '54.7 percent',
#   '12.0%',
#   'approximately 9%',
#   '6.2%',
#   '7.6 percent',
#   '93.5%',
#   '15.6%',
#   '4–6%',
#   'About 30%',
#   'About 50%',
#   '19.2%',
#   '54 percent',
#   'nearly forty percent',
#   '13.2%',
#   'about 34%',
#   '53.4%',
#   '30.45%',
#   '94%',
#   'less than 40 percent',
#   '89.38%',
#   'over 40%',
#   'at least 80 percent',
#   '24.8%',
#   '53%',
#   '15.2%',
#   '26.2%',
#   '98 percent',
#   '13.0 percent',
#   '24.5%',
#   '25.3%',
#   'as late as 1878',
#   '18.74%',
#   'about 0.03%',
#   '30.04%',
#   'no more than 858 Officers and',
#   'less than 12%',
#   '13.0%',
#   'class and',
#   '9%',
#   '2.79%',
#   'about 90%',
#   '0.039%',
#   '86.3%',
#   'only 5–10%',
#   'more than 63%',
#   '2.89%',
#   'About 75%',
#   '11.1%',
#   'over 95%',
#   '55.4%',
#   'Around 21–24%',
#   'nearly 9%',
#   'some 10–12%',
#   'about 4.2%',
#   '1.15%',
#   '43 percent',
#   'only 1%',
#   'up to 20%',
#   '1.5% to 2%',
#   '30 percent',
#   'no less than one percent',
#   '34.7%',
#   'about 0.5%',
#   '5.25%',
#   '145%',
#   'An estimated',
#   'over 96%',
#   'no more than 10%',
#   '39.1%',
#   '67.8%',
#   'Over 35%',
#   '56.7%',
#   '32.3%',
#   '81%',
#   'Some 6.8%',
#   'only about 3%',
#   '61.35%',
#   '38%',
#   '29.4%',
#   '14–41%',
#   'between 8.5% and 9.75%',
#   '1.99%',
#   '45.0%',
#   'about 60 percent',
#   '2.65%',
#   'over 86 percent',
#   '22.79%',
#   '77.1%',
#   '21 percent',
#   '7 percent',
#   '97%',
#   'more than 45%',
#   '5.9%',
#   '18-percent',
#   '32.9%',
#   '10% to 212%',
#   'Over 99%',
#   '48.2%',
#   '25 Hz',
#   'a full 41%',
#   '4.13%',
#   '44.16%',
#   '86%',
#   '4.40 percent',
#   '73.3%',
#   '5.7% to',
#   'approximately 7%',
#   'up to 30%',
#   'around 25%',
#   'around 11%',
#   'Sixty-four percent',
#   '6.4%',
#   '10–60 percent',
#   'up to 5%',
#   'About 5%',
#   '6.7 percent',
#   '12.2%',
#   '14.8 percent',
#   'Sixty-two percent',
#   '29.1%',
#   '20.51%',
#   '94 percent',
#   '16.2%',
#   '50 percent',
#   '77.0%',
#   '24.9%',
#   '54.5%',
#   'only about 4.6%',
#   '0.7% and 0.5%',
#   'approximately 78.9%',
#   'nearly 18%',
#   'up to 65%',
#   '25.1%',
#   'only about 70%',
#   '12.3 percent',
#   '13.7%',
#   'Approximately 61%',
#   'more than 40%',
#   '6 to 10 percent',
#   '74%',
#   '94.8%',
#   '36.6%',
#   'around 27%',
#   '60.41%',
#   '41.6%',
#   'less than 40%',
#   '60.6%',
#   '7% to 8%',
#   '60.8%',
#   '11.9%',
#   'around 90%',
#   '23.6%',
#   'About 60%',
#   'over 1.6%',
#   'roughly 78%',
#   'between 3% and 5%',
#   '10–30%',
#   '38.3%',
#   '72%',
#   '7.8%',
#   '500%',
#   '0.61%',
#   '74.9%',
#   '58%',
#   'Twenty four percent',
#   'less than 50%',
#   '65.4%',
#   'more than 15%',
#   'Only about 25%',
#   'between 7% to 8%',
#   '34.36%',
#   'up to 40%',
#   '68.2%',
#   'some 95%',
#   '5.1%',
#   '6%',
#   'the 52%',
#   'between 0.5% and 20%',
#   'about 57 percent',
#   '71%',
#   '48.9%',
#   '60%',
#   'at least 29%',
#   '10.40%',
#   '33.7%',
#   '77.3%',
#   'about 0.25%',
#   '4.01%',
#   '21% and 34%',
#   'more than 30 percent',
#   '38.5%',
#   '15.55%',
#   '73%',
#   'over 82%',
#   '39.5%',
#   '89% to 100%',
#   '80-percent',
#   '18.5 percent',
#   '120,000(8%',
#   'up to 85%',
#   '1–2%',
#   '8.2%',
#   '100%',
#   '2.5% to',
#   'over 65%',
#   '45.5%',
#   'forty-nine percent',
#   '53 percent',
#   '5.4%',
#   '77%',
#   'as high as 40 percent',
#   '13.4%',
#   'around 20%',
#   '37%',
#   '12 percent',
#   '62 percent',
#   '39% to 93%',
#   '0.7 percent',
#   'seventy-eight percent',
#   '50 Hz',
#   'only 12 percent',
#   'around 4% to 6%',
#   '7.60%',
#   '89.7 percent',
#   '10 percent',
#   '6% to 9.2%',
#   '80 percent',
#   '2.48%',
#   '3.7%',
#   '99.4%',
#   'An estimated 1.9 percent',
#   '10.85%',
#   '32.4%',
#   '17.3%',
#   '56.4%',
#   '0.82%',
#   'some 66.4%',
#   '8.0%',
#   'just 1.6 percent',
#   'only 19%',
#   '14.58%',
#   'under 2%',
#   '2.3%',
#   '3.0%',
#   'nearly 7 percent',
#   '33.1%',
#   '35%',
#   '35.7%',
#   'eighty-seven percent',
#   '62.1%',
#   'only 11 percent',
#   '−7.3%',
#   '0.66%',
#   '51%',
#   'Forty-one percent',
#   '44.5%',
#   '17.9 percent',
#   '9.72%',
#   'more than 75%',
#   '99.28%',
#   '30.5%',
#   '3 percent',
#   '65 percent',
#   ...]}

# %%
import pickle

with open('ne_collection.obj', 'wb') as handle:
    pickle.dump(ne_collection, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
question = squad['train']['question'][0]
question
# Out:
# 'When did Beyonce start becoming popular?'

# %%
import random
for question in squad['train']['question'][1000:1010]:
    question_chunks = question.split()
    doc = ner( question )
    res = [(X.text, X.label_) for X in doc.ents]

    if not res:
        continue 

    idx = random.randint(0, len(res) - 1)

    text, label = res[idx]

    substitution = random.choice(ne_collection[label])

    new_question = question.replace( text, substitution )
    print( f'{question} vs {new_question}')
# Out:
# What nationality were the two friends who served as a pivotal influence in Frédéric's life while in Paris? vs What nationality were the two friends who served as a pivotal influence in Frédéric's life while in Roman Hispania?
# Julian Fontana tried to find his way where before moving to Paris? vs Käfigturm tried to find his way where before moving to Paris?
# Where did Julian Fontana fail to get established? vs Where did Tito fail to get established?
# Who did Chopin know that became rich in Paris? vs Who did Chopin know that became rich in Assassin?
# Which friend of Chopin became like an older brother to him? vs Which friend of the RMS St Helena became like an older brother to him?
# Which friend took on the role of several jobs to help Chopin including copyist? vs Which friend took on the role of several jobs to help Ali including copyist?
# Where were Chopin and Fontana students together? vs Where were Chopin and Ye Olde students together?
# Who gave Frédéric his first significant public approval in regards to his compositions? vs Who gave Frédéric his 400th significant public approval in regards to his compositions?
# On what date did Frédéric give his first performance at the Salle Pleyel? vs On what date did Frédéric give his 4th performance at the Salle Pleyel?
# What is stated as a hindrance for Frédéric's ability to perform in large concert spaces? vs What is stated as a hindrance for Divine Redeemer School's ability to perform in large concert spaces?
