# %%
import pandas as pd

# _corpus_substitution
df = pd.read_json('NaturalQuestionsDev2_corpus_substitution.jsonl', lines=True)
#df = df.drop(columns=['uid', 'metadata', 'original_example', 'dataset'])
df = df[1:]
df.reset_index(drop=True, inplace=True)
print(df.iloc[0])
print(df.iloc[0]['query'])
print(df.iloc[0]['context'])

print(len(df))
df = df.drop_duplicates(subset=['query'])
print(len(df))


for i, row in df.iterrows():
    print(row['query'], ' => ', row['gold_answers'])
# Out:
# dataset                                                           NaN
# uid                                                    corpus-sub-0_1
# query                    who wrote the song photograph by ringo starr
# context             <P> `` Photograph '' is a song by English musi...
# metadata                                                           {}
# is_substitute                                                     1.0
# gold_answers        [{'text': 'Tagore', 'spans': None, 'ner_label'...
# original_example                                                  1.0
# Name: 0, dtype: object
# who wrote the song photograph by ringo starr
# ...
